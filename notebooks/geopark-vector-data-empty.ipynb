# %% [markdown]
# Let's get started working with spatial data! In this notebook you'll learn how to open and plot GeoDataFrames as shapefiles (.shp) in `Python` using the `Geopandas` library. We'll also demonstrate how to make an interactive map using `Folium`.
#
# You can read more about working with **Geopandas** here:
# > * [Earth Data Science Textbook](https://www.earthdatascience.org/courses/use-data-open-source-python/intro-vector-data-python/spatial-data-vector-shapefiles/)
# > * [Geopandas Documentation](https://geopandas.org/en/stable/getting_started/introduction.html)
#
# Read more about **Folium** here:
# > * [Earth Data Science Textbook](https://www.earthdatascience.org/tutorials/introduction-to-leaflet-animated-maps/)
# > * [Folium Documentation](https://python-visualization.github.io/folium/latest/getting_started.html)
#
# From Earth Data Science textbook:
#
# ![](https://www.earthdatascience.org/images/courses/earth-analytics/spatial-data/points-lines-polygons-vector-data-types.png)

# %%
# Import Python libraries
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd

# %%
# Download Colombia boundary
colombia_boundary_url = ("https://maps.princeton.edu/download/file/tufts-colombia-municipalities-11-shapefile.zip")

# Open Colombia boundary .shp with geopandas
boundary_colombia = gpd.read_file(colombia_boundary_url)
boundary_colombia
# Out:
#      ID_ESPACIA  AREA_OFICI          ENTIDAD_TE NOM_DEPART  \
# 0         23189      637.49  Cabecera Municipal    CÓRDOBA
# 1         23570      795.00  Cabecera Municipal    CÓRDOBA
# 2         23068     1932.62  Cabecera Municipal    CÓRDOBA
# 3         23580     1650.73  Cabecera Municipal    CÓRDOBA
# 4         23686      472.57  Cabecera Municipal    CÓRDOBA
# ...         ...         ...                 ...        ...
# 1123      23675      335.03  Cabecera Municipal    CÓRDOBA
# 1124      23672      210.75  Cabecera Municipal    CÓRDOBA
# 1125      23168      320.42  Cabecera Municipal    CÓRDOBA
# 1126      23670      212.44  Cabecera Municipal    CÓRDOBA
# 1127      23182      584.90  Cabecera Municipal    CÓRDOBA
#
#                    NOM_MUNICI COD_DEPTO  \
# 0              CIÉNAGA DE ORO        23
# 1                PUEBLO NUEVO        23
# 2                      AYAPEL        23
# 3           PUERTO LIBERTADOR        23
# 4                  SAN PELAYO        23
# ...                       ...       ...
# 1123  SAN BERNARDO DEL VIENTO        23
# 1124               SAN ANTERO        23
# 1125                    CHIMÁ        23
# 1126  SAN ANDRÉS DE SOTAVENTO        23
# 1127                    CHINÚ        23
#
#                                                geometry
# 0     POLYGON ((-75.71080 8.98249, -75.71119 8.98358...
# 1     POLYGON ((-75.25133 8.32489, -75.25144 8.32489...
# 2     POLYGON ((-75.18418 8.39828, -75.18352 8.39893...
# 3     POLYGON ((-75.51257 7.94787, -75.51315 7.94683...
# 4     POLYGON ((-75.71080 8.98249, -75.71024 8.98264...
# ...                                                 ...
# 1123  POLYGON ((-75.86320 9.42472, -75.86318 9.42231...
# 1124  POLYGON ((-75.86320 9.42472, -75.86297 9.42476...
# 1125  POLYGON ((-75.71080 8.98249, -75.71213 8.98212...
# 1126  POLYGON ((-75.57457 9.02304, -75.57458 9.02421...
# 1127  POLYGON ((-75.57457 9.02304, -75.57438 9.02306...
#
# [1128 rows x 7 columns]

# %%
boundary_colombia.plot()
# Out:
# <Axes: >

# %%
# Map using explore
#boundary_colombia.explore()

# %% [markdown]
# ## **Department Boundaries**

# %%
# Colombia Admin boundaries
dept_url = ("https://stacks.stanford.edu/file/druid:mj028ht5751/data.zip")

# Open data with geopandas
dept_gdf = gpd.read_file(dept_url)
dept_gdf
# Out:
#       ID_0  ISO    NAME_0  ID_1    NAME_1  ID_2             NAME_2    HASC_2  \
# 0       53  COL  Colombia     1  Amazonas     1         El Encanto  CO.AM.EE
# 1       53  COL  Colombia     1  Amazonas     2        La Chorrera  CO.AM.LC
# 2       53  COL  Colombia     1  Amazonas     3         La Pedrera  CO.AM.LP
# 3       53  COL  Colombia     1  Amazonas     4            Leticia  CO.AM.LE
# 4       53  COL  Colombia     1  Amazonas     5      Mirití-Paraná  CO.AM.MI
# ...    ...  ...       ...   ...       ...   ...                ...       ...
# 1060    53  COL  Colombia    32   Vichada  1061       La Primavera  CO.VD.LP
# 1061    53  COL  Colombia    32   Vichada  1062     Puerto Carreño  CO.VD.PC
# 1062    53  COL  Colombia    32   Vichada  1063  San Jose de Ocune     CO.VD
# 1063    53  COL  Colombia    32   Vichada  1064         Santa Rita       NaN
# 1064    53  COL  Colombia    32   Vichada  1065      Santa Rosalía  CO.VD.SR
#
#       CCN_2  CCA_2                      TYPE_2                   ENGTYPE_2  \
# 0         0    NaN  Corregimiento Departamento  Corregimiento Departamento
# 1         0    NaN  Corregimiento Departamento  Corregimiento Departamento
# 2         0    NaN  Corregimiento Departamento  Corregimiento Departamento
# 3         0    NaN                   Municipio                Municipality
# 4         0    NaN  Corregimiento Departamento  Corregimiento Departamento
# ...     ...    ...                         ...                         ...
# 1060      0    NaN                   Municipio                Municipality
# 1061      0    NaN                   Municipio                Municipality
# 1062      0    NaN                   Municipio                Municipality
# 1063      0    NaN                   Municipio                Municipality
# 1064      0    NaN                   Municipio                Municipality
#
#       NL_NAME_2      VARNAME_2  \
# 0           NaN            NaN
# 1           NaN            NaN
# 2           NaN            NaN
# 3           NaN            NaN
# 4           NaN  Miriti Parana
# ...         ...            ...
# 1060        NaN            NaN
# 1061        NaN            NaN
# 1062        NaN            NaN
# 1063        NaN            NaN
# 1064        NaN            NaN
#
#                                                geometry
# 0     POLYGON ((-73.95367 -1.10172, -73.95241 -1.098...
# 1     POLYGON ((-71.98020 -1.81340, -71.96750 -1.831...
# 2     MULTIPOLYGON (((-72.61586 -0.92313, -72.59810 ...
# 3     POLYGON ((-70.28952 -3.83257, -70.28491 -3.822...
# 4     POLYGON ((-70.21880 -0.48360, -70.20900 -0.489...
# ...                                                 ...
# 1060  POLYGON ((-68.54120 5.43700, -68.55100 5.43360...
# 1061  POLYGON ((-67.49085 6.14925, -67.49323 6.13791...
# 1062  POLYGON ((-71.09520 2.84550, -71.09780 3.34340...
# 1063  POLYGON ((-68.90510 3.65020, -68.87930 3.92910...
# 1064  POLYGON ((-70.38830 4.67342, -70.39980 4.66840...
#
# [1065 rows x 15 columns]

# %%
# Explore department boundary data using .info()
dept_gdf.info()

# Look at "NAME_2" column values
dept_gdf["NAME_2"]
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1065 entries, 0 to 1064
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID_0       1065 non-null   int64
#  1   ISO        1065 non-null   object
#  2   NAME_0     1065 non-null   object
#  3   ID_1       1065 non-null   int64
#  4   NAME_1     1065 non-null   object
#  5   ID_2       1065 non-null   int64
#  6   NAME_2     1065 non-null   object
#  7   HASC_2     1062 non-null   object
#  8   CCN_2      1065 non-null   int64
#  9   CCA_2      0 non-null      float64
#  10  TYPE_2     1056 non-null   object
#  11  ENGTYPE_2  1056 non-null   object
#  12  NL_NAME_2  0 non-null      float64
#  13  VARNAME_2  87 non-null     object
#  14  geometry   1065 non-null   geometry
# dtypes: float64(2), geometry(1), int64(4), object(8)
# memory usage: 124.9+ KB
# 0              El Encanto
# 1             La Chorrera
# 2              La Pedrera
# 3                 Leticia
# 4           Mirití-Paraná
#               ...
# 1060         La Primavera
# 1061       Puerto Carreño
# 1062    San Jose de Ocune
# 1063           Santa Rita
# 1064        Santa Rosalía
# Name: NAME_2, Length: 1065, dtype: object

# %%
# Select Amazonas municipality
amazonas = boundary_colombia[boundary_colombia["NOM_DEPART"] == 'AMAZONAS']
amazonas
# Out:
#    ID_ESPACIA  AREA_OFICI                   ENTIDAD_TE NOM_DEPART  \
# 33      91530     8410.09  Corregimiento Departamental   AMAZONAS
# 34      91263    10690.26  Corregimiento Departamental   AMAZONAS
# 35      91536    13641.05  Corregimiento Departamental   AMAZONAS
# 36      91798     9137.71  Corregimiento Departamental   AMAZONAS
# 37      91001     6186.26                   CAP. DEPTO   AMAZONAS
# 38      91540     1515.58           Cabecera Municipal   AMAZONAS
# 39      91460    16891.79  Corregimiento Departamental   AMAZONAS
# 40      91430     1506.18  Corregimiento Departamental   AMAZONAS
# 41      91405    12738.75  Corregimiento Departamental   AMAZONAS
# 42      91669    14759.22  Corregimiento Departamental   AMAZONAS
# 43      91407    13679.19  Corregimiento Departamental   AMAZONAS
#
#                                         NOM_MUNICI COD_DEPTO  \
# 33             PUERTO ALEGRÍA (Cor. Departamental)        91
# 34                 EL ENCANTO (Cor. Departamental)        91
# 35               PUERTO ARICA (Cor. Departamental)        91
# 36                   TARAPACÁ (Cor. Departamental)        91
# 37                                         LETICIA        91
# 38                                   PUERTO NARIÑO        91
# 39  MIRITÍ-PARANÁ (Campoamor) (Cor. Departamental)        91
# 40        LA VICTORIA (Pacoa) (Cor. Departamental)        91
# 41                LA CHORRERA (Cor. Departamental)        91
# 42     SANTANDER (Araracuara) (Cor. Departamental)        91
# 43                 LA PEDRERA (Cor. Departamental)        91
#
#                                              geometry
# 33  POLYGON ((-74.38851 -0.55351, -74.38102 -0.551...
# 34  POLYGON ((-71.77392 -2.17489, -71.77594 -2.176...
# 35  POLYGON ((-71.77392 -2.17489, -71.77593 -2.171...
# 36  POLYGON ((-69.71428 -3.00261, -69.71601 -3.002...
# 37  POLYGON ((-69.71428 -3.00261, -69.88301 -3.940...
# 38  POLYGON ((-70.33734 -3.20082, -70.33744 -3.211...
# 39  POLYGON ((-71.99610 -0.26831, -71.98758 -0.268...
# 40  POLYGON ((-71.44949 0.02042, -71.44805 0.02046...
# 41  POLYGON ((-71.99031 -1.53227, -71.99052 -1.553...
# 42  POLYGON ((-70.72647 -1.43024, -70.73084 -1.434...
# 43  POLYGON ((-69.43422 -1.07068, -69.43131 -1.072...

# %%
# Select Puerto Nariño
pn = amazonas[amazonas["NOM_MUNICI"] == 'PUERTO NARIÑO']
pn
# Out:
#    ID_ESPACIA  AREA_OFICI          ENTIDAD_TE NOM_DEPART     NOM_MUNICI  \
# 38      91540     1515.58  Cabecera Municipal   AMAZONAS  PUERTO NARIÑO
#
#    COD_DEPTO                                           geometry
# 38        91  POLYGON ((-70.33734 -3.20082, -70.33744 -3.211...

# %%
# Plot Puerto Nariño
pn.plot()
# Out:
# <Axes: >

# %%
#pn.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f57f4d2391b0bd5e3cf192cb1c89eb2d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f57f4d2391b0bd5e3cf192cb1c89eb2d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f57f4d2391b0bd5e3cf192cb1c89eb2d = L.map(
#                 &quot;map_f57f4d2391b0bd5e3cf192cb1c89eb2d&quot;,
#                 {
#                     center: [-3.5407874172239855, -70.50779602586502],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f57f4d2391b0bd5e3cf192cb1c89eb2d);
#
#
#
#
#
#             var tile_layer_7bce780f3ad8de734ab604b72941853e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f57f4d2391b0bd5e3cf192cb1c89eb2d);
#
#
#             map_f57f4d2391b0bd5e3cf192cb1c89eb2d.fitBounds(
#                 [[-3.880750005192277, -70.71324730246612], [-3.200824829255694, -70.30234474926394]],
#                 {}
#             );
#
#
#         function geo_json_6175682ac28c140a59ab61cd80c9cf1f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_6175682ac28c140a59ab61cd80c9cf1f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_6175682ac28c140a59ab61cd80c9cf1f_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_6175682ac28c140a59ab61cd80c9cf1f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_6175682ac28c140a59ab61cd80c9cf1f_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_6175682ac28c140a59ab61cd80c9cf1f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_6175682ac28c140a59ab61cd80c9cf1f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_6175682ac28c140a59ab61cd80c9cf1f = L.geoJson(null, {
#                 onEachFeature: geo_json_6175682ac28c140a59ab61cd80c9cf1f_onEachFeature,
#
#                 style: geo_json_6175682ac28c140a59ab61cd80c9cf1f_styler,
#                 pointToLayer: geo_json_6175682ac28c140a59ab61cd80c9cf1f_pointToLayer
#         });
#
#         function geo_json_6175682ac28c140a59ab61cd80c9cf1f_add (data) {
#             geo_json_6175682ac28c140a59ab61cd80c9cf1f
#                 .addData(data)
#                 .addTo(map_f57f4d2391b0bd5e3cf192cb1c89eb2d);
#         }
#             geo_json_6175682ac28c140a59ab61cd80c9cf1f_add({&quot;bbox&quot;: [-70.71324730246612, -3.880750005192277, -70.30234474926394, -3.200824829255694], &quot;features&quot;: [{&quot;bbox&quot;: [-70.71324730246612, -3.880750005192277, -70.30234474926394, -3.200824829255694], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-70.3373434928535, -3.200824829255694], [-70.33744418064613, -3.211870841405162], [-70.34652244161143, -3.3617763539394], [-70.36633772699676, -3.6897468326232774], [-70.36410778910286, -3.68974504529808], [-70.35967364579753, -3.6908549035580216], [-70.35523798802603, -3.6938204640931156], [-70.35006222143235, -3.698269980890847], [-70.34710456505957, -3.70

# %%
# Plot the Colombia geodataframe using Matplotlib

# %% [markdown]
# ## **Petroleum & Gas (2013)**

# %%
# Oil & Gas (point shapefile)

# Citation: Petroleum and Gas Extraction Sites Colombia 2013. [Shapefile].
# Sistema de Inforrmacion Ambiental de Colombia (SIAC).
# Retrieved from https://maps.princeton.edu/catalog/tufts-colombia-petroleumgasexplotation-sites-13

oil_url = ("https://maps.princeton.edu/download/file/tufts-colombia-petroleumgasexplotation-sites-13-shapefile.zip")

# Open the oil and gas data using geopandas
oil_gdf = gpd.read_file(oil_url)
oil_gdf
# Out:
#         CORPORACIO    DEPTO       ESTADO      EXP       FECHA  \
# 0    CORPOAMAZONIA  CAQUETA  SEGUIMIENTO  LAM4353  04/06/2009
# 1    CORPOAMAZONIA  CAQUETA  SEGUIMIENTO  LAM4353  04/06/2009
# 2    CORPOAMAZONIA  CAQUETA  SEGUIMIENTO  LAM4353  04/06/2009
# 3       CORPOCESAR    CESAR  SEGUIMIENTO  LAM4539  21/12/2009
# 4       CORPOCESAR    CESAR  SEGUIMIENTO  LAM4539  21/12/2009
# ..             ...      ...          ...      ...         ...
# 941            CAM    HUILA  SEGUIMIENTO  LAM3703  07/06/2007
# 942            CAM    HUILA  SEGUIMIENTO  LAM3703  07/06/2007
# 943    CORPOBOYACA   BOYACA  SEGUIMIENTO  LAM1994  17/12/2003
# 944    CORPOBOYACA   BOYACA  SEGUIMIENTO  LAM1994  17/12/2003
# 945            CAM    HUILA  SEGUIMIENTO  LAM3779  25/07/2007
#
#                    MUNIC                                           PROYECTO  \
# 0    SAN JOSE DEL FRAGUA  AREA DE PERFORACION EXPLORATORIA TOPOYACO-TOPO...
# 1    SAN JOSE DEL FRAGUA  AREA DE PERFORACION EXPLORATORIA TOPOYACO-TOPO...
# 2    SAN JOSE DEL FRAGUA  AREA DE PERFORACION EXPLORATORIA TOPOYACO-TOPO...
# 3                EL PASO  LICENCIA AMBIENTAL GLOBAL PARA EL PROYECTO CAM...
# 4                EL PASO  LICENCIA AMBIENTAL GLOBAL PARA EL PROYECTO CAM...
# ..                   ...                                                ...
# 941              PALERMO                      POZO EXPLORATORIO GUANABANA-2
# 942              PALERMO                      POZO EXPLORATORIO GUANABANA-1
# 943        PUERTO BOYACA                                       POZO BALSO-1
# 944        PUERTO BOYACA                                     POZO MORICHE-1
# 945                 AIPE                       POZO EXPLORATORIO ARRAYAN-1.
#
#          REGION  RESOLUCION                                 SOLICITANT  \
# 0      AMAZONIA      1035.0  TRAYECTORIA OIL AND GAS SUCURSAL COLOMBIA
# 1      AMAZONIA      1035.0  TRAYECTORIA OIL AND GAS SUCURSAL COLOMBIA
# 2      AMAZONIA      1035.0  TRAYECTORIA OIL AND GAS SUCURSAL COLOMBIA
# 3         NORTE      2563.0          TEXICAN OIL LTD SUCURSAL COLOMBIA
# 4         NORTE      2563.0          TEXICAN OIL LTD SUCURSAL COLOMBIA
# ..          ...         ...                                        ...
# 941  CENTRO SUR      1007.0                                 HOCOL S.A.
# 942  CENTRO SUR      1007.0                                 HOCOL S.A.
# 943      CENTRO      1378.0             MANSAROVAR ENERGY COLOMBIA LTD
# 944      CENTRO      1378.0             MANSAROVAR ENERGY COLOMBIA LTD
# 945  CENTRO SUR      1318.0                             ECOPETROL S.A.
#
#                       geometry
# 0    POINT (-76.22626 1.14385)
# 1    POINT (-76.23612 1.13818)
# 2    POINT (-76.22893 1.14162)
# 3    POINT (-73.68522 9.70236)
# 4    POINT (-73.67319 9.71454)
# ..                         ...
# 941  POINT (-75.38347 2.77870)
# 942  POINT (-75.38787 2.76720)
# 943  POINT (-74.53784 6.17697)
# 944  POINT (-74.53605 6.19696)
# 945  POINT (-75.29862 3.17782)
#
# [946 rows x 11 columns]

# %%
# Print all the entries in the 'SOLICITANT' column using .to_string(index=False)
oil_gdf["SOLICITANT"].unique()
# Out:
# array(['TRAYECTORIA OIL AND GAS SUCURSAL COLOMBIA',
#        'TEXICAN OIL LTD SUCURSAL COLOMBIA', 'DRUMMOND LTD',
#        'PETRÓLEOS DEL NORTE S.A.', 'OCCIDENTAL ANDINA LLC',
#        'PETROLEOS DEL MAR', 'CONSORCIO EMPESA - NCT',
#        'META PETROLEUM LTD', 'CEPSA COLOMBIA S.A. - CEPCOLSA',
#        'META PETROLEUM CORP', 'PETROMINERALES COLOMBIA LTD',
#        'ECOPETROL S.A.', 'VETRA EXPLORACIÓN Y PRODUCCIÓN COLOMBIA S.A.',
#        'PETROMINERALES COLOMBIA LTD.', 'UNIÓN TEMPORAL II & B',
#        'SERINPET LTDA.', 'SADEVEN S.A.', 'OCCIDENTAL DE COLOMBIA INC.',
#        'VAROSA ENERGY LTDA', 'COLOMBIA ENERGY DEVELOPMENT CO',
#        'BP EXPLORATION COMPANY (COLOMBIA) LTD.',
#        'PERENCO COLOMBIA LIMITED',
#        'SOLANA PETROLEUM EXPLORATION COLOMBIA LIMITED',
#        'PETROBRAS COLOMBIA LIMITED', 'KAPPA RESOURCES COLOMBIA',
#        'ECOPETROL S.A', 'PETROSANTANDER (COLOMBIA) INC',
#        'REPSOL EXPLORACIÓN COLOMBIA S.A.', 'CARIBBEAN OIL SERVICES',
#        'PACIFIC STRATUS ENERGY COLOMBIA CORP',
#        'INTEROIL COLOMBIA EXPLORATION AND PRODUCTION',
#        'COLOMBIA ENERGY DEVELOPMENT CO.', 'HOCOL S.A.',
#        'MAXUS DE COLOMBIA INC', 'PETROBRAS INTERNACIONAL BRASPETRO BV.',
#        'BP- SANTIAGO OIL COMPANY',
#        'COMPAÑÍA OPERADORA PETROCOLOMBIA S.A. - COPP S.A.',
#        'CONSORCIO COLOMBIA ENERGY',
#        'PETROLEOS COLOMBIANOS LIMITED PETROCOL LTD', 'HOCOL S.A',
#        'ECOPETROL', 'EMERALD ENERGY PLC SUCURSAL COLOMBIA',
#        'GULFSANDS PETROLEUM COLOMBIA LTD', 'OCCIDENTAL DE COLOMBIA INC',
#        'MAXIM WELL SERVICES LTDA - MWS', 'PETROTESTING COLOMBIA S.A.',
#        'CONSORCIO CAMPOS DE PRODUCCIÓN - CCP', 'VETRA COLOMBIA',
#        'EXXON MOBIL DE COLOMBIA S.A.', 'PARKO SERVICES S.A.',
#        'UNION TEMPORAL ANDINA', 'R3 EXPLORACIÓN Y PRODUCCIÓN S.A.',
#        'CONSORCIO CANAGUARO',
#        'INGENIERIA CONSTRUCCIONES Y EQUIPOS CONEQUIPOS ING. LTDA',
#        'UNION TEMPORAL MORICHE', 'GRAN TIERRA ENERGY COLOMBIA',
#        'REFINERIA DE CARTAGENA S.A.', 'CHEVRON PETROLEUM COMPANY',
#        'DRUMMOND', 'COPLEX COLOMBIA LIMITED',
#        'COMPAÑIA OPERADORA PETROCOLOMBIA S.A. - COPP S.A.',
#        'MANSAROVAR ENERGY COLOMBIA LTD'], dtype=object)

# %%
unique_solicitant_count = oil_gdf["SOLICITANT"].nunique()
print("Number of unique values in 'SOLICITANT' column:", unique_solicitant_count)
# Out:
# Number of unique values in 'SOLICITANT' column: 62

# %%
print(oil_gdf['SOLICITANT'].to_string(index=False))
# Out:
#          TRAYECTORIA OIL AND GAS SUCURSAL COLOMBIA
#          TRAYECTORIA OIL AND GAS SUCURSAL COLOMBIA
#          TRAYECTORIA OIL AND GAS SUCURSAL COLOMBIA
#                  TEXICAN OIL LTD SUCURSAL COLOMBIA
#                  TEXICAN OIL LTD SUCURSAL COLOMBIA
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                           PETRÓLEOS DEL NORTE S.A.
#                           PETRÓLEOS DEL NORTE S.A.
#                              OCCIDENTAL ANDINA LLC
#                              OCCIDENTAL ANDINA LLC
#                              OCCIDENTAL ANDINA LLC
#                              OCCIDENTAL ANDINA LLC
#                                  PETROLEOS DEL MAR
#                             CONSORCIO EMPESA - NCT
#                             CONSORCIO EMPESA - NCT
#                             CONSORCIO EMPESA - NCT
#                             CONSORCIO EMPESA - NCT
#                                 META PETROLEUM LTD
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                     CEPSA COLOMBIA S.A. - CEPCOLSA
#                                META PETROLEUM CORP
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                        PETROMINERALES COLOMBIA LTD
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#                                     ECOPETROL S.A.
#       VETRA EXPLORACIÓN Y PRODUCCIÓN COLOMBIA S.A.
#       VETRA EXPLORACIÓN Y PRODUCCIÓN COLOMBIA S.A.
#       VETRA EXPLORACIÓN Y PRODUCCIÓN COLOMBIA S.A.
#       VETRA EXPLORACIÓN Y PRODUCCIÓN COLOMBIA S.A.
#       VETRA EXPLORACIÓN Y PRODUCCIÓN COLOMBIA S.A.
#                       PETROMINERALES COLOMBIA LTD.
#                       PETROMINERALES COLOMBIA LTD.
#                       PETROMINERALES COLOMBIA LTD.
#                       PETROMINERALES COLOMBIA LTD.
#                              UNIÓN TEMPORAL II & B
#                              UNIÓN TEMPORAL II & B
#                              UNIÓN TEMPORAL II & B
#                              UNIÓN TEMPORAL II & B
#                                     ECOPETROL S.A.
#                                     SERINPET LTDA.
#                                       SADEVEN S.A.
#                        OCCIDENTAL DE COLOMBIA INC.
#                        OCCIDENTAL DE COLOMBIA INC.
#                                 VAROSA ENERGY LTDA
#                                 VAROSA ENERGY LTDA
#                                 VAROSA ENERGY LTDA
#                                 VAROSA ENERGY LTDA
#                     COLOMBIA ENERGY DEVELOPMENT CO
#                     COLOMBIA ENERGY DEVELOPMENT CO
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#      SOLANA PETROLEUM EXPLORATION COLOMBIA LIMITED
#      SOLANA PETROLEUM EXPLORATION COLOMBIA LIMITED
#                         PETROBRAS COLOMBIA LIMITED
#                         PETROBRAS COLOMBIA LIMITED
#                         PETROBRAS COLOMBIA LIMITED
#                         PETROBRAS COLOMBIA LIMITED
#                         PETROBRAS COLOMBIA LIMITED
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#                           KAPPA RESOURCES COLOMBIA
#                           KAPPA RESOURCES COLOMBIA
#                           KAPPA RESOURCES COLOMBIA
#                           KAPPA RESOURCES COLOMBIA
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#                      PETROSANTANDER (COLOMBIA) INC
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#                   REPSOL EXPLORACIÓN COLOMBIA S.A.
#                   REPSOL EXPLORACIÓN COLOMBIA S.A.
#                   REPSOL EXPLORACIÓN COLOMBIA S.A.
#                   REPSOL EXPLORACIÓN COLOMBIA S.A.
#                   REPSOL EXPLORACIÓN COLOMBIA S.A.
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                             CARIBBEAN OIL SERVICES
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#               PACIFIC STRATUS ENERGY COLOMBIA CORP
#               PACIFIC STRATUS ENERGY COLOMBIA CORP
#               PACIFIC STRATUS ENERGY COLOMBIA CORP
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                    COLOMBIA ENERGY DEVELOPMENT CO.
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#                              MAXUS DE COLOMBIA INC
#                     COLOMBIA ENERGY DEVELOPMENT CO
#                     COLOMBIA ENERGY DEVELOPMENT CO
#                     COLOMBIA ENERGY DEVELOPMENT CO
#                     COLOMBIA ENERGY DEVELOPMENT CO
#                     COLOMBIA ENERGY DEVELOPMENT CO
#                     COLOMBIA ENERGY DEVELOPMENT CO
#                     COLOMBIA ENERGY DEVELOPMENT CO
#                     COLOMBIA ENERGY DEVELOPMENT CO
#                     COLOMBIA ENERGY DEVELOPMENT CO
#                     COLOMBIA ENERGY DEVELOPMENT CO
#                     COLOMBIA ENERGY DEVELOPMENT CO
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                         PETROBRAS COLOMBIA LIMITED
#                         PETROBRAS COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#              PETROBRAS INTERNACIONAL BRASPETRO BV.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#                           BP- SANTIAGO OIL COMPANY
#       VETRA EXPLORACIÓN Y PRODUCCIÓN COLOMBIA S.A.
#       VETRA EXPLORACIÓN Y PRODUCCIÓN COLOMBIA S.A.
#                                      ECOPETROL S.A
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#  COMPAÑÍA OPERADORA PETROCOLOMBIA S.A. - COPP S.A.
#  COMPAÑÍA OPERADORA PETROCOLOMBIA S.A. - COPP S.A.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#                      PETROSANTANDER (COLOMBIA) INC
#                      PETROSANTANDER (COLOMBIA) INC
#                      PETROSANTANDER (COLOMBIA) INC
#                      PETROSANTANDER (COLOMBIA) INC
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#                         PETROBRAS COLOMBIA LIMITED
#       VETRA EXPLORACIÓN Y PRODUCCIÓN COLOMBIA S.A.
#       VETRA EXPLORACIÓN Y PRODUCCIÓN COLOMBIA S.A.
#                          CONSORCIO COLOMBIA ENERGY
#                          CONSORCIO COLOMBIA ENERGY
#                          CONSORCIO COLOMBIA ENERGY
#                          CONSORCIO COLOMBIA ENERGY
#                          CONSORCIO COLOMBIA ENERGY
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#         PETROLEOS COLOMBIANOS LIMITED PETROCOL LTD
#         PETROLEOS COLOMBIANOS LIMITED PETROCOL LTD
#         PETROLEOS COLOMBIANOS LIMITED PETROCOL LTD
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#                                          HOCOL S.A
#                                          HOCOL S.A
#                                          HOCOL S.A
#                                          HOCOL S.A
#                                         HOCOL S.A.
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#         PETROLEOS COLOMBIANOS LIMITED PETROCOL LTD
#         PETROLEOS COLOMBIANOS LIMITED PETROCOL LTD
#         PETROLEOS COLOMBIANOS LIMITED PETROCOL LTD
#         PETROLEOS COLOMBIANOS LIMITED PETROCOL LTD
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                          ECOPETROL
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                          ECOPETROL
#                                          ECOPETROL
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                          ECOPETROL
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                          ECOPETROL
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#       INTEROIL COLOMBIA EXPLORATION AND PRODUCTION
#                                      ECOPETROL S.A
#               EMERALD ENERGY PLC SUCURSAL COLOMBIA
#                           KAPPA RESOURCES COLOMBIA
#                           KAPPA RESOURCES COLOMBIA
#                   GULFSANDS PETROLEUM COLOMBIA LTD
#                         OCCIDENTAL DE COLOMBIA INC
#                         OCCIDENTAL DE COLOMBIA INC
#                         OCCIDENTAL DE COLOMBIA INC
#                         OCCIDENTAL DE COLOMBIA INC
#                         OCCIDENTAL DE COLOMBIA INC
#                         OCCIDENTAL DE COLOMBIA INC
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#             BP EXPLORATION COMPANY (COLOMBIA) LTD.
#                                      ECOPETROL S.A
#                                      ECOPETROL S.A
#                     MAXIM WELL SERVICES LTDA - MWS
#                     MAXIM WELL SERVICES LTDA - MWS
#                     MAXIM WELL SERVICES LTDA - MWS
#                         PETROTESTING COLOMBIA S.A.
#                         PETROTESTING COLOMBIA S.A.
#                         PETROTESTING COLOMBIA S.A.
#                         PETROTESTING COLOMBIA S.A.
#                         PETROTESTING COLOMBIA S.A.
#                         PETROTESTING COLOMBIA S.A.
#                         PETROTESTING COLOMBIA S.A.
#               CONSORCIO CAMPOS DE PRODUCCIÓN - CCP
#               CONSORCIO CAMPOS DE PRODUCCIÓN - CCP
#                                 META PETROLEUM LTD
#                                     VETRA COLOMBIA
#                         PETROTESTING COLOMBIA S.A.
#                         PETROTESTING COLOMBIA S.A.
#                         PETROTESTING COLOMBIA S.A.
#                         PETROTESTING COLOMBIA S.A.
#                       EXXON MOBIL DE COLOMBIA S.A.
#                       EXXON MOBIL DE COLOMBIA S.A.
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           KAPPA RESOURCES COLOMBIA
#                           KAPPA RESOURCES COLOMBIA
#                           KAPPA RESOURCES COLOMBIA
#                           KAPPA RESOURCES COLOMBIA
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                                PARKO SERVICES S.A.
#                                PARKO SERVICES S.A.
#                                PARKO SERVICES S.A.
#                                PARKO SERVICES S.A.
#                                PARKO SERVICES S.A.
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                              UNION TEMPORAL ANDINA
#                              UNION TEMPORAL ANDINA
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                           PERENCO COLOMBIA LIMITED
#                                          ECOPETROL
#                                          ECOPETROL
#                           PERENCO COLOMBIA LIMITED
#                   R3 EXPLORACIÓN Y PRODUCCIÓN S.A.
#                                CONSORCIO CANAGUARO
#                                CONSORCIO CANAGUARO
# INGENIERIA CONSTRUCCIONES Y EQUIPOS CONEQUIPOS ...
#      SOLANA PETROLEUM EXPLORATION COLOMBIA LIMITED
#                             UNION TEMPORAL MORICHE
#                             UNION TEMPORAL MORICHE
#                             UNION TEMPORAL MORICHE
#                        GRAN TIERRA ENERGY COLOMBIA
#                        GRAN TIERRA ENERGY COLOMBIA
#                        GRAN TIERRA ENERGY COLOMBIA
#                        GRAN TIERRA ENERGY COLOMBIA
#                                          ECOPETROL
#                        REFINERIA DE CARTAGENA S.A.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                          CHEVRON PETROLEUM COMPANY
#                          CHEVRON PETROLEUM COMPANY
#                          CHEVRON PETROLEUM COMPANY
#                          CHEVRON PETROLEUM COMPANY
#                          CHEVRON PETROLEUM COMPANY
#                          CHEVRON PETROLEUM COMPANY
#                          CHEVRON PETROLEUM COMPANY
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                           DRUMMOND
#                                           DRUMMOND
#                                           DRUMMOND
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                       DRUMMOND LTD
#                                         HOCOL S.A.
#               EMERALD ENERGY PLC SUCURSAL COLOMBIA
#                                          ECOPETROL
#                                          ECOPETROL
#                           KAPPA RESOURCES COLOMBIA
#                           KAPPA RESOURCES COLOMBIA
#                           KAPPA RESOURCES COLOMBIA
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                      PETROSANTANDER (COLOMBIA) INC
#                      PETROSANTANDER (COLOMBIA) INC
#                                          ECOPETROL
#                                          ECOPETROL
#                                          ECOPETROL
#                                          ECOPETROL
#                                          ECOPETROL
#                                          ECOPETROL
#                                          ECOPETROL
#                            COPLEX COLOMBIA LIMITED
#  COMPAÑIA OPERADORA PETROCOLOMBIA S.A. - COPP S.A.
#                          CHEVRON PETROLEUM COMPANY
#                                          ECOPETROL
#                                     ECOPETROL S.A.
#                     MANSAROVAR ENERGY COLOMBIA LTD
#                     MANSAROVAR ENERGY COLOMBIA LTD
#                     MANSAROVAR ENERGY COLOMBIA LTD
#                     MANSAROVAR ENERGY COLOMBIA LTD
#                     MANSAROVAR ENERGY COLOMBIA LTD
#                     MANSAROVAR ENERGY COLOMBIA LTD
#                     MANSAROVAR ENERGY COLOMBIA LTD
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                                         HOCOL S.A.
#                     MANSAROVAR ENERGY COLOMBIA LTD
#                     MANSAROVAR ENERGY COLOMBIA LTD
#                                     ECOPETROL S.A.

# %%
# Plot Oil and Gas (2013) Locations on the Colombia boundary using Matplotlib
fig, ax = plt.subplots(figsize=(20,10))

boundary_colombia.plot(ax =ax, edgecolor ="black", color= "beige")

oil_gdf.plot(ax =ax, marker ='^', color = "green", markersize = 30)
plt.title( "Oil & Gas in Colombia 2023")
plt.show()

# %% [markdown]
# ## **Rivers**

# %%
# Open Colombia rivers
rivers_url = ("https://maps.princeton.edu/download/file/tufts-colombia-major-rivers-11-shapefile.zip")

# Open rivers using geopandas
import pandas as pd
import geopandas as gpd
rivers_gdf = gpd.read_file(rivers_url)
rivers_gdf
# Out:
#                  gml_id              nombre_geo symbol  \
# 0      Drenaje_DobleQ.1             RÍO BANADIA      3
# 1      Drenaje_DobleQ.2         RÍO SAN BARTOLO      3
# 2      Drenaje_DobleQ.3  BRAZUELO DE LA ROMPIDA      3
# 3      Drenaje_DobleQ.4                     NaN      3
# 4      Drenaje_DobleQ.5                  Estero    NaN
# ..                  ...                     ...    ...
# 272  Drenaje_DobleQ.263                RÍO TOLA      3
# 273  Drenaje_DobleQ.264         ESTERO SECADERO      3
# 274  Drenaje_DobleQ.265                     NaN      3
# 275  Drenaje_DobleQ.266               RÍO PATÍA      3
# 276  Drenaje_DobleQ.272        QUEBRADA BARRERA      3
#
#                                               geometry
# 0    POLYGON ((-71.77688 6.98672, -71.77690 6.98673...
# 1    POLYGON ((-74.39558 6.68462, -74.39369 6.68327...
# 2    POLYGON ((-73.98540 7.23822, -73.98589 7.23747...
# 3    POLYGON ((-71.58675 6.46682, -71.58673 6.46678...
# 4    POLYGON ((-70.76271 5.50627, -70.76281 5.50574...
# ..                                                 ...
# 272  POLYGON ((-78.28576 2.60301, -78.28437 2.58979...
# 273  POLYGON ((-78.28165 2.43932, -78.28157 2.44015...
# 274  POLYGON ((-77.64400 2.93037, -77.64378 2.92925...
# 275  POLYGON ((-78.41314 2.18721, -78.41418 2.18572...
# 276  POLYGON ((-78.50477 2.50733, -78.50347 2.50717...
#
# [277 rows x 4 columns]

# %%
# Examine the data using .info()
rivers_gdf.info()

# Print the rivers Coordinate Reference System (CRS)--> sistema de referencia WGS 84
rivers_gdf.crs
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gml_id      277 non-null    object
#  1   nombre_geo  259 non-null    object
#  2   symbol      276 non-null    object
#  3   geometry    277 non-null    geometry
# dtypes: geometry(1), object(3)
# memory usage: 8.8+ KB
# <Geographic 2D CRS: GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84" ...>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - lon[east]: Longitude (degree)
# - lat[north]: Latitude (degree)
# Area of Use:
# - undefined
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Plot the rivers data using .plot()

fig, ax = plt.subplots(figsize=(40,20))

boundary_colombia.plot(ax =ax, edgecolor ="black", color= "white", linewidth = 0.5)

rivers_gdf.plot(ax =ax, color="blue", edgecolor= "darkblue", linewidth = 1)
plt.title( "Rivers")
plt.show()

# %% [markdown]
# ## **Roads**

# %%
# Open Columbia roads (850,000 entries!)
roads_url = ("https://maps.princeton.edu/download/file/tufts-colombia-roads-11-shapefile.zip")

# Open the roads data using geopandas
roads_gdf = gpd.read_file(roads_url)
roads_gdf
# Out:
#        tipo_via estado_sup numero_car accesibili nombre_geo clas_tipov  \
# 0           6.0  Sin Valor  Sin Valor  Sin Valor        NaN          6
# 1           6.0  Sin Valor  Sin Valor  Sin Valor        NaN          6
# 2           6.0  Sin Valor  Sin Valor  Sin Valor        NaN          6
# 3           5.0       3306       3502       3601        NaN          5
# 4           1.0       3301       3501       3600        NaN          1
# ...         ...        ...        ...        ...        ...        ...
# 11395       4.0       3306       3502       3600        NaN          4
# 11396       5.0       3306       3502       3601        NaN          5
# 11397       5.0       3306       3502       3601        NaN          5
# 11398       5.0       3306       3502       3601        NaN          5
# 11399       5.0       3306       3502       3601        NaN          5
#
#           esc_vis  type                                           geometry
# 0             0.0     3  LINESTRING (-70.48271 4.24664, -70.48295 4.245...
# 1             0.0     3  LINESTRING (-70.50524 4.26742, -70.50498 4.267...
# 2             0.0     3  LINESTRING (-70.19799 4.24444, -70.19862 4.243...
# 3             0.0     3  LINESTRING (-67.45190 3.51188, -67.45173 3.513...
# 4      17000000.0     1  LINESTRING (-76.01828 1.87813, -76.00653 1.880...
# ...           ...   ...                                                ...
# 11395         0.0     3  LINESTRING (-75.19593 9.10449, -75.19566 9.105...
# 11396         0.0     3  LINESTRING (-72.17559 11.37238, -72.17546 11.3...
# 11397         0.0     3  LINESTRING (-72.12112 11.37323, -72.12121 11.3...
# 11398  17000000.0     1  LINESTRING (-72.78346 11.64916, -72.78437 11.6...
# 11399  17000000.0     1  LINESTRING (-72.78182 11.64785, -72.78346 11.6...
#
# [11400 rows x 9 columns]

# %%
# Explore data using .info()
roads_gdf.info()
roads_gdf.plot()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 11400 entries, 0 to 11399
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tipo_via    11400 non-null  float64
#  1   estado_sup  11400 non-null  object
#  2   numero_car  11400 non-null  object
#  3   accesibili  11400 non-null  object
#  4   nombre_geo  11 non-null     object
#  5   clas_tipov  11202 non-null  object
#  6   esc_vis     11400 non-null  float64
#  7   type        11400 non-null  int64
#  8   geometry    11400 non-null  geometry
# dtypes: float64(2), geometry(1), int64(1), object(5)
# memory usage: 801.7+ KB
# <Axes: >

# %% [markdown]
# ## **Airports**

# %%
# Download Airports data
col_airports_url = "https://maps.princeton.edu/download/file/tufts-colombia-mainairports-14-shapefile.zip"

# Open airports data using geopandas
col_airports_gdf = gpd.read_file(col_airports_url)
col_airports_gdf
# Out:
#             gml_id  id_aero                                           nombre  \
# 0    Aeropuertos.1      1.0                 AEROPUERTO INTERNACIONAL EL EDÉN
# 1    Aeropuertos.2      2.0       AEROPUERTO INTERNACIONAL ERNESTO CORTISSOZ
# 2    Aeropuertos.3      3.0               AEROPUERTO INTERNACIONAL EL DORADO
# 3    Aeropuertos.4      4.0               AEROPUERTO INTERNACIONAL PALONEGRO
# 4    Aeropuertos.5      5.0  AEROPUERTO INTERNACIONAL ALFONSO BONILLA ARAGÓN
# ..             ...      ...                                              ...
# 84  Aeropuertos.79     79.0                    AEROPUERTO SAN PEDRO DE URABÁ
# 85  Aeropuertos.80     80.0                AEROPUERTO ALBERTO LLERAS CAMARGO
# 86  Aeropuertos.81     81.0                    AEROPUERTO DE TUNJA (CERRADO)
# 87  Aeropuertos.82     82.0                         AEROPUERTO GONZALO MEJÍA
# 88  Aeropuertos.87     87.0                          BASE AÉREA GERMÁN OLANO
#
#                        tipo administra          estadocon  n_desti_in  \
# 0             INTERNACIONAL        ANI  EN ESTRUCTURACION         1.0
# 1             INTERNACIONAL        ANI  EN ESTRUCTURACION         3.0
# 2             INTERNACIONAL        ANI       CONCESIONADO        51.0
# 3             INTERNACIONAL        ANI       CONCESIONADO         1.0
# 4             INTERNACIONAL        ANI       CONCESIONADO         8.0
# ..                      ...        ...                ...         ...
# 84  REGIONAL - NO PASAJEROS  AEROCIVIL                NaN         0.0
# 85  REGIONAL - NO PASAJEROS  AEROCIVIL                NaN         0.0
# 86  REGIONAL - NO PASAJEROS  AEROCIVIL                NaN         0.0
# 87  REGIONAL - NO PASAJEROS  AEROCIVIL                NaN         0.0
# 88                  MILITAR  AEROCIVIL                NaN         0.0
#
#    cod_iata cod_oaci          ciudad_loc           municipio       departamen  \
# 0       AXM     SKAR             ARMENIA          LA TEBAIDA          QUINDÍO
# 1       BAQ     SKBQ        BARRANQUILLA             SOLEDAD        ATLÁNTICO
# 2       BOG     SKBO         BOGOTÁ D.C.         BOGOTÁ D.C.      BOGOTÁ D.C.
# 3       BGA     SKBG         BUCARAMANGA             LEBRIJA        SANTANDER
# 4       CLO     SKCL                CALI             PALMIRA  VALLE DEL CAUCA
# ..      ...      ...                 ...                 ...              ...
# 84      NPD   SK-021  SAN PEDRO DE URABÁ  SAN PEDRO DE URABÁ        ANTIOQUIA
# 85      SOX     SKSO            SOGAMOSO            SOGAMOSO           BOYACÁ
# 86      NaN     SKTJ               TUNJA               TUNJA           BOYACÁ
# 87      TRB     SKTU               TURBO               TURBO        ANTIOQUIA
# 88      PAL     SKPQ          PALANQUERO          PALANQUERO     CUNDINAMARCA
#
#                            observacio        latitud       longitud  \
# 0                       INTERNACIONAL  04°27'09.99 N  75°45'59.21 O
# 1                       INTERNACIONAL  10°53'22.52 N  74°46'50.95 O
# 2                       INTERNACIONAL  04°42'05.74 N  74°08'49.01 O
# 3                       INTERNACIONAL  07°07'35.40 N  73°11'05.20 O
# 4                       INTERNACIONAL  03°32'35.60 N  76°22'53.70 O
# ..                                ...            ...            ...
# 84  SIN SERVICIO REGULAR DE PASAJEROS     04°40'19 N     76°46'39 O
# 85  SIN SERVICIO REGULAR DE PASAJEROS  05°40'38.35 N  72°58'13.06 O
# 86  SIN SERVICIO REGULAR DE PASAJEROS  05°32'28.98 N  73°20'40.18 O
# 87  SIN SERVICIO REGULAR DE PASAJEROS     08°04'28 N     76°44'28 O
# 88                            MILITAR  05°29'01.00 N  74°39'26.50 O
#
#     lat_decima  long_decim            mi_style                    geometry
# 0     4.452775  -75.766447  Symbol (35, 0, 12)   POINT (-75.76645 4.45278)
# 1    10.889589  -74.780819  Symbol (35, 0, 12)  POINT (-74.78082 10.88959)
# 2     4.701594  -74.146947  Symbol (35, 0, 12)   POINT (-74.14695 4.70159)
# 3     7.126500  -73.184778  Symbol (35, 0, 12)   POINT (-73.18478 7.12650)
# 4     3.543222  -76.381583  Symbol (35, 0, 12)   POINT (-76.38158 3.54322)
# ..         ...         ...                 ...                         ...
# 84    4.671944  -76.777500  Symbol (35, 0, 12)   POINT (-76.77750 4.67194)
# 85    5.677319  -72.970294  Symbol (35, 0, 12)   POINT (-72.97029 5.67732)
# 86    5.541383  -73.344494  Symbol (35, 0, 12)   POINT (-73.34449 5.54138)
# 87    8.074444  -76.741111  Symbol (35, 0, 12)   POINT (-76.74111 8.07444)
# 88    5.483611  -74.657361  Symbol (35, 0, 12)   POINT (-74.65736 5.48361)
#
# [89 rows x 19 columns]

# %%
# Determine number of airport types per admin designation using pd.crosstab()

cross_tab = pd.crosstab(index=col_airports_gdf["administra"], columns=col_airports_gdf["tipo"])

print(cross_tab)
cross_tab
# Out:
# tipo        INTERNACIONAL  MILITAR  NACIONAL  NACIONAL - REGIONAL  REGIONAL  \
# administra
# AEROCIVIL               2        7         7                   33         1
# ANI                    11        0        10                    1         0
#
# tipo        REGIONAL - NO PASAJEROS
# administra
# AEROCIVIL                        16
# ANI                               1
# tipo        INTERNACIONAL  MILITAR  NACIONAL  NACIONAL - REGIONAL  REGIONAL  \
# administra
# AEROCIVIL               2        7         7                   33         1
# ANI                    11        0        10                    1         0
#
# tipo        REGIONAL - NO PASAJEROS
# administra
# AEROCIVIL                        16
# ANI                               1

# %%
cross_tab = pd.crosstab(col_airports_gdf["tipo"], col_airports_gdf["administra"])
cross_tab
# Out:
# administra               AEROCIVIL  ANI
# tipo
# INTERNACIONAL                    2   11
# MILITAR                          7    0
# NACIONAL                         7   10
# NACIONAL - REGIONAL             33    1
# REGIONAL                         1    0
# REGIONAL - NO PASAJEROS         16    1

# %%
cross_tab.plot(kind="bar")
plt.xlabel('administrador')
plt.ylabel('Cuenta')
# Out:
# Text(0, 0.5, 'Cuenta')

# %%
# Plot the airports data using .plot()

col_airports_gdf.plot()
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(40,20))

boundary_colombia.plot(ax =ax, edgecolor ="black", color= "white", linewidth = 0.5)

roads_gdf.plot(ax =ax, color="brown", linewidth = 0.2)
col_airports_gdf.plot(ax =ax, markersize = 50,edgecolor="darkgrey", column="tipo", legend = True)
rivers_gdf.plot(ax =ax, color="blue", edgecolor= "darkblue", linewidth = 1)

plt.title( "Airports, Rivers & Roads")
##plt.legend()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/plotting.py:732: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(values.dtype):

# %%
# Looking at airport data as csv (pandas df) [from the previous notebook]
col_airports_df = pd.read_csv("https://ourairports.com/countries/CO/airports.csv")
col_airports_df

# %%
# Create geodataframe from pandas df


# Convert to shp


# Call the 'new' col_airports_gdf2

# %%
# Select only international, military and national airports from col_airports_gdf

# %%
# Create map of Colombia boundaries, rivers, airports, and roads on the same axis using Matplotlib

# %%
# Conservation Areas
conservation_url = "https://maps.princeton.edu/download/file/tufts-colombia-prioritizedenvconsareas-12-shapefile.zip"

conservation_gdf = gpd.read_file(conservation_url)
conservation_gdf

# %%
# Forest areas
forest_url = "https://maps.princeton.edu/download/file/tufts-colombia-forest-reserves-12-shapefile.zip"

forest_gdf = gpd.read_file(forest_url)
forest_gdf

# %%
# Plot the conservation areas using .plot() and color by 'PRIORIDAD'

# %%
# Plot Colombia boundaries and forested areas colored by 'nombre_zrf' on same axis using Matplotlib

# %%
# Mining Areas
mining_url = "https://maps.princeton.edu/download/file/tufts-colombia-miningprojects-13-shapefile.zip"
mining_gdf = gpd.read_file(mining_url)
mining_gdf.plot()

# %%
# Petroleum / Gas exploration 2014 - *Polygon
gas_2014_url = "https://maps.princeton.edu/download/file/tufts-colombia-petroleumgasexplorationareas-14-shapefile.zip"

# Open data using geopandas and plot using .plot() color by 'SOLICITANT'

# %%
# Plot the oil and gas (2014) polygon on the Colombia boundary using Matplotlib

# %% [markdown]
# ## **Focusing on one Department (Cauca)**
#
#
# *   Select Department
# *   Clip roads, rivers, airports to Cauca
# *   Plot all layers on common axis

# %%
# Select Cauca (Deptarmento)

# %%
# Select Florencia (Municipio)

# %%
# Print the CRS for Cacua and the rivers_gdf data

# %%
# Reproject rivers_gdf to Cauca CRS (EPSG:4326)

# %%
# Clip rivers to Cauca boundary using gpd.clip() and plot using .plot()

# %%
# Reproject col_airports_gdf to Cauca CRS


# Clip airports to Cauca boundary


# Plot Cauca airports

# %%
# Reproject oil/gas to Cauca CRS



# Clip oil & gas to Cauca

# %%
# Reproject roads to Cauca CRS



# Clip roads to Cauca

# %%
# Plot roads, rivers, oil & gas within Cauca using Matplotlib

# %% [markdown]
# ## **Focus on one municipality (Puetro Asis)**

# %%
# Zoom in on PUERTO ASÍS

# Extract PUERTO ASÍS from Putumayo boundary


# Clip oil gas points 2013 to PUERTO ASÍS boundary


# Clip rivers to PUERTO ASÍS boundary


# Clip roads to PUERTO ASÍS boundary


# Clip airports to PUERTO ASÍS boundary


# Clip gas/oil polygon 2014 to PUERTO ASÍS boundary


# Plot Puerto Asis boundary and clipped oil and gas


# Define and place legend

# %% [markdown]
# ## **Interactive Maps with Folium**

# %%
# Create an interactive map of airports using folium

import folium

#Define coordinates of where we want to center our map
map_center_coords = [5.0, -72.0]

#Create the map
my_map = folium.Map(location = map_center_coords, zoom_start = 6)

# for lat,long in zip(bigger_air_and_heli.geometry.y, bigger_air_and_heli.geometry.x):
#     folium.Marker(
#         location=[lat, long],
#         #popup=['name']
#     ).add_to(my_map)

for _, airport_info in inter_mil_nat.iterrows():
    folium.Marker(
        location=[airport_info.geometry.y, airport_info.geometry.x],
        popup=airport_info['nombre']
    ).add_to(my_map)

my_map

# %% [markdown]
# ## **Looking at Geology Data** (hosted on CyVerse)

# %%
# Open Geology of S America gdf

geology_url = (
    "https://data.cyverse.org/dav-anon/iplant/home/shared/"
    "earthlab/geopark/geo6ag.zip")

geology_gdf = gpd.read_file(geology_url)
geology_gdf

# %%
# Clip S America geology to Colombia boundary

geog_clipped = geology_gdf.clip(cauca.geometry)
geog_clipped

# %%
# Plot clipped geology
fig, ax = plt.subplots(figsize=(12,20))
geog_clipped.plot(ax=ax,
                  column='GLG',
                  legend=True)
plt.title("Geologic Map of Cauca Deptartmento Colombia", fontsize=25)
plt.show()
